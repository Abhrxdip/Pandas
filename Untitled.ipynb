# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c','d']
my_lists=[10,20,30,40]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(my_lists,index=labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
pd.Series(d)

# %% [markdown]
# # Pandas Learning Notebook
# Progressive examples for beginners

# %%
# Create sample employee data
employees_data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 35, 40, 28],
    'Salary': [50000, 60000, 75000, 80000, 55000],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}

df_employees = pd.DataFrame(employees_data)
print("Employee DataFrame:")
print(df_employees)
